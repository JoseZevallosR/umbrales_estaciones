# %%
import geopandas as gpd
import os
import pandas as pd
import matplotlib.pylab as plt
import shapely.speedups
# %config Completer.use_jedi = False #for auto complete code

# %%
file = 'D:/Proyectos_GitHub/umbrales_estaciones/data/Maestro/Maestro.xlsx'
df = pd.read_excel(file)

# %%
df
# Out:
#     INVENTARIO_SINCERADO  DZ          NOMBRE_ESTACION    CODIGO     CATEGORIA  \
# 0                     NO   1                   ALAMOR    200322  CONVENCIONAL
# 1                     NO   1                   ALAMOR  47E0D438    AUTOMATICA
# 2                     NO   1      BOCATOMA_CHIPILLICO  47E0E1A2    AUTOMATICA
# 3                     NO   1           BOCATOMA_ZAMBA  4723C424    AUTOMATICA
# 4                     NO   1                CABO_INGA  47E01126    AUTOMATICA
# ..                   ...  ..                      ...       ...           ...
# 250                   NO  13   PUENTE_ISLA_CABANILLAS    210406  CONVENCIONAL
# 251                   NO  13  PUENTE_LOROCO_CALLACAME    210502  CONVENCIONAL
# 252                   NO  13             PUENTE_RAMIS    210101  CONVENCIONAL
# 253                   NO  13         PUENTE_ZAPATILLA    270503  CONVENCIONAL
# 254                   NO  13                RIO_VERDE    270300  CONVENCIONAL
#
#     CLASIFICACION         TIPO    COMUNICACION FECHA_DE_INSTALACION  \
# 0             HLM  HIDROLÓGICA      VOZ Y DATA             01/02/17
# 1             EHA  HIDROLÓGICA  SATELITAL GOES             17/12/14
# 2             EHA  HIDROLÓGICA  SATELITAL GOES             05/04/15
# 3             EHA  HIDROLÓGICA  SATELITAL GOES             13/05/14
# 4             EHA  HIDROLÓGICA  SATELITAL GOES             05/12/14
# ..            ...          ...             ...                  ...
# 250           HLM  HIDROLÓGICA      VOZ Y DATA             16/07/94
# 251           HLG  HIDROLÓGICA      VOZ Y DATA             09/07/94
# 252           HLG  HIDROLÓGICA      VOZ Y DATA             01/01/56
# 253           HLM  HIDROLÓGICA      VOZ Y DATA             01/01/76
# 254           HLG  HIDROLÓGICA      VOZ Y DATA             22/11/61
#
#     ESTADO_FUNCIONAMIENTO ESTADO_OPERATIVIDAD    LATITUD   LONGITUD  \
# 0             FUNCIONANDO           OPERATIVO  -4.474008 -80.399152
# 1             FUNCIONANDO           OPERATIVO  -4.477490 -80.397895
# 2             FUNCIONANDO           OPERATIVO  -4.714203 -80.118248
# 3             FUNCIONANDO           OPERATIVO  -4.664442 -79.897353
# 4             FUNCIONANDO           OPERATIVO  -3.978733 -80.399381
# ..                    ...                 ...        ...        ...
# 250           FUNCIONANDO           OPERATIVO -15.471833 -70.224020
# 251           FUNCIONANDO           OPERATIVO -16.570650 -69.322780
# 252           FUNCIONANDO           OPERATIVO -15.255309 -69.873786
# 253           FUNCIONANDO           OPERATIVO -16.138603 -69.578730
# 254           FUNCIONANDO           OPERATIVO -15.684272 -70.600017
#
#     Lat_Sexagesimal Lot_Sexagesimal  ALTITUD DEPARTAMENTO  PROVINCIA  \
# 0      -4°28'26.43"   -80°23'56.95"    127.0        PIURA    SULLANA
# 1      -4°28'38.96"   -80°23'52.42"    116.0        PIURA    SULLANA
# 2      -4°42'51.13"     -80°7'5.69"    340.0        PIURA      PIURA
# 3      -4°39'51.99"   -79°53'50.47"    633.0        PIURA    AYABACA
# 4      -3°58'43.44"   -80°23'57.77"    160.0       TUMBES     TUMBES
# ..              ...             ...      ...          ...        ...
# 250    -15°28'18.6"   -70°13'26.47"   3838.0         PUNO  SAN ROMAN
# 251   -16°34'14.34"   -69°19'22.01"   3862.0         PUNO   CHUCUITO
# 252   -15°15'19.11"   -69°52'25.63"   3825.0         PUNO   HUANCANE
# 253    -16°8'18.97"   -69°34'43.43"   3846.0         PUNO  EL COLLAO
# 254    -15°41'3.38"    -70°36'0.06"   4140.0         PUNO      LAMPA
#
#         DISTRITO
# 0       LANCONES
# 1       LANCONES
# 2      LAS LOMAS
# 3         PAIMAS
# 4    SAN JACINTO
# ..           ...
# 250      JULIACA
# 251      KELLUYO
# 252       TARACO
# 253        ILAVE
# 254  SANTA LUCIA
#
# [255 rows x 19 columns]

# %%
points_gdf = gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df.LONGITUD,df.LATITUD),crs='EPSG:4326')
# Out:
# C:\Users\jose\anaconda3\envs\work_env\lib\site-packages\geopandas\array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)

# %%
points_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
clima =gpd.read_file('../data/shp/clasif_clima_peru/clasif_clima_1981_2010.shp')

# %%
clima
# Out:
#            CODIGO       AREA_km2  \
# 0        D (i) B'   12697.595114
# 1        C (i) B'   17711.776736
# 2        B (r) B'  110961.424157
# 3        C (r) B'   39967.787497
# 4        B (r) C'    2970.635697
# 5        C (r) A'    7586.886045
# 6        B (r) A'  262834.583955
# 7    B (o , i) B'   16004.549593
# 8    B (o , i) C'  133384.411494
# 9    C (o , i) B'    3857.431292
# 10       B (r) D'   15390.916116
# 11       D (i) A'     421.722656
# 12       C (i) A'    2967.483850
# 13   C (i , p) A'      57.399545
# 14       B (i) C'    6396.386624
# 15       A (r) B'   28244.474579
# 16   C (o , i) C'   18971.750352
# 17       A (r) C'   12567.474065
# 18       A (r) D'    2353.329286
# 19       C (i) C'   34482.941628
# 20       B (i) D'    3140.140468
# 21   B (o , i) D'    1848.385753
# 22       B (i) E'      65.850217
# 23   C (o , i) D'     310.044428
# 24       C (i) D'   13927.730429
# 25       C (i) E'     419.190321
# 26   C (o , i) E'     536.720776
# 27   C (i , p) B'     303.915203
# 28       D (i) C'    6420.164363
# 29       D (i) D'      82.149498
# 34  MULTIPOLYGON (((-71.18983 -16.58270, -71.18521...
# 35  MULTIPOLYGON (((-70.73350 -16.78401, -70.73113...
# 36  MULTIPOLYGON (((-73.90163 -10.70391, -73.90059...
# 37  POLYGON ((-76.26102 -10.91281, -76.26127 -10.9...
# 38  MULTIPOLYGON (((-68.95611 -16.19738, -68.91840...
# 39  MULTIPOLYGON (((-71.50662 -16.20542, -71.50663...
# 40  MULTIPOLYGON (((-70.71858 -18.10500, -70.71857...

# %%
shapely.speedups.enable() 
# enable shapely.speedups which makes queries running faster.
sub_df=[]
for i in range(clima.shape[0]):
    
    pip_mask = points_gdf.within(clima.loc[i, 'geometry']) 
    # selecting the polygon's geometry field to filter out points that 
    # are not overlaid
    pip_data = df.loc[pip_mask]
    
    pip_data['COD_Clima']= clima.CODIGO[i]
    
    sub_df.append(pip_data)
    
maestro = pd.concat((sub_df))
# Out:
# C:\Users\jose\anaconda3\envs\work_env\lib\site-packages\shapely\speedups\__init__.py:50: RuntimeWarning: shapely.speedups not available
#   warnings.warn("shapely.speedups not available", RuntimeWarning)
# C:\Users\jose\AppData\Local\Temp\ipykernel_27224\4019328912.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pip_data['COD_Clima']= clima.CODIGO[i]

# %%
maestro = pd.concat((sub_df))

# %%
maestro
# Out:
#     INVENTARIO_SINCERADO  DZ NOMBRE_ESTACION    CODIGO     CATEGORIA  \
# 51                    NO   3        EL_TAMBO    211003  CONVENCIONAL
# 52                    NO   3        EL_TAMBO  47E0A2A8    AUTOMATICA
# 60                    NO   3    PUENTE_COINA    211004  CONVENCIONAL
# 61                    NO   3    PUENTE_COINA  472E74CC    AUTOMATICA
# 63                    NO   3  PUENTE_PALMIRA    211002  CONVENCIONAL
# ..                   ...  ..             ...       ...           ...
# 212                   NO  10    PUENTE_PEREZ    230001  CONVENCIONAL
# 213                   NO  10  PUENTE_TOCACHE    230700  CONVENCIONAL
# 218                   NO  10     TINGO_MARIA  47270400    AUTOMATICA
# 219                   NO  10     TINGO_MARIA    221820  CONVENCIONAL
# 220                   SI  10         TOCACHE  47E2E456    AUTOMATICA
#
#     CLASIFICACION                TIPO    COMUNICACION FECHA_DE_INSTALACION  \
# 51            HLM         HIDROLÓGICA        SIN_DATO  2022-04-08 00:00:00
# 52           EHMA  HIDROMETEOROLÓGICA  SATELITAL GOES             06/02/15
# 60            HLM         HIDROLÓGICA        SIN_DATO             SIN_DATO
# 61           EHMA  HIDROMETEOROLÓGICA  SATELITAL GOES             SIN_DATO
# 63            HLM         HIDROLÓGICA        SIN_DATO             SIN_DATO
# ..            ...                 ...             ...                  ...
# 212           HLM         HIDROLÓGICA        PLANILLA             01/11/17
# 213           HLG         HIDROLÓGICA      VOZ Y DATA             01/01/03
# 218          EHMA  HIDROMETEOROLÓGICA  SATELITAL GOES             31/12/00
# 219           HLM         HIDROLÓGICA      VOZ Y DATA             22/09/97
# 220           EHA         HIDROLÓGICA  SATELITAL GOES             31/12/99
#
#     ESTADO_FUNCIONAMIENTO  ...   LATITUD   LONGITUD  Lat_Sexagesimal  \
# 51            FUNCIONANDO  ... -7.573976 -78.706554     -7°34'26.31"
# 52            FUNCIONANDO  ... -7.573976 -78.706554     -7°34'26.31"
# 60            FUNCIONANDO  ... -7.796364 -78.380122     -7°47'46.91"
# 61            FUNCIONANDO  ... -7.796364 -78.380122     -7°47'46.91"
# 63            FUNCIONANDO  ... -7.549189 -78.810514     -7°32'57.08"
# ..                    ...  ...       ...        ...              ...
# 212           FUNCIONANDO  ... -9.346940 -75.982500     -9°20'48.98"
# 213           FUNCIONANDO  ... -8.184750 -76.507890       -8°11'5.1"
# 218           FUNCIONANDO  ... -9.296010 -76.002070     -9°17'45.64"
# 219            PARALIZADA  ... -9.296010 -76.002070     -9°17'45.64"
# 220           FUNCIONANDO  ... -8.184750 -76.507890       -8°11'5.1"
#
#     Lot_Sexagesimal ALTITUD  DEPARTAMENTO      PROVINCIA  \
# 51    -78°42'23.59"   688.0   LA LIBERTAD     GRAN CHIMÚ
# 52    -78°42'23.59"   688.0   LA LIBERTAD     GRAN CHIMÚ
# 60    -78°22'48.44"  1823.0   LA LIBERTAD         OTUZCO
# 61    -78°22'48.44"  1823.0   LA LIBERTAD         OTUZCO
# 63    -78°48'37.85"   647.0   LA LIBERTAD     GRAN CHIMÚ
# ..              ...     ...           ...            ...
# 212      -75°58'57"   675.0       HUANUCO  LEONCIO PRADO
# 213    -76°30'28.4"   483.0    SAN MARTIN        TOCACHE
# 218     -76°0'7.45"   646.0       HUANUCO  LEONCIO PRADO
# 219     -76°0'7.45"   646.0       HUANUCO  LEONCIO PRADO
# 220    -76°30'28.4"   483.0    SAN MARTIN        TOCACHE
#
#                   DISTRITO                    geometry COD_Clima
# 51                  MARMOT  POINT (-78.70655 -7.57398)  D (i) B'
# 52                  MARMOT  POINT (-78.70655 -7.57398)  D (i) B'
# 60                  USQUIL  POINT (-78.38012 -7.79636)  D (i) B'
# 61                  USQUIL  POINT (-78.38012 -7.79636)  D (i) B'
# 63                  CASCAS  POINT (-78.81051 -7.54919)  D (i) B'
# ..                     ...                         ...       ...
# 212  MARIANO DAMASO BERAÚN  POINT (-75.98250 -9.34694)  A (r) A'
# 213                TOCACHE  POINT (-76.50789 -8.18475)  A (r) A'
# 218              RUPA-RUPA  POINT (-76.00207 -9.29601)  A (r) A'
# 219              RUPA-RUPA  POINT (-76.00207 -9.29601)  A (r) A'
# 220                TOCACHE  POINT (-76.50789 -8.18475)  A (r) A'
#
# [254 rows x 21 columns]
